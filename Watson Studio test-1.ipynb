# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **AKshay Kulkarni**

# %% [markdown]
# Data Scientist

# %% [markdown]
# *I'm interested in Data Science because it helps to find out hidden facts in data.*

# %% [markdown]
# *Libararies & tools that are  present in Data Science gives immense options to  get the valuable informations from the avialbale data.*

# %% [markdown]
# ### Data Science has vast  options to  study.

# %% [markdown]
# ### There are  different languages & tools available in Data Science.

# %%
"Data Science has vast options to study."
# Out:
# 'Data Science has vast options to study.'

# %% [markdown]
# | State Name | Capital |
# | ---------- | ------- |
# | Maharashtra | Mumbai |
# | Gujarat | Surat |
# | Rajasthan | Jaipur |

# %% [markdown]
# **Data Science Languages**

# %% [markdown]
# - Python
# - SQL
# - R
# - Java
# - Scala

# %% [markdown]
# [Novypro](https://www.novypro.com/profile_projects/akshaykulkarni)
